# %%
import pandas as pd
import seaborn as sns

# %%
df =pd.read_csv('https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DA0101EN-SkillsNetwork/labs/Data%20files/automobileEDA.csv')
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
sns.regplot(x='highway-mpg',y='price',data=df)

# %%
sns.regplot(x='engine-size',y='price',data=df)

# %%
l = ['horsepower', 'curb-weight', 'engine-size', 'highway-mpg','price','normalized-losses','length','width','city-mpg']
sns.regplot(x='horsepower',y='price',data=df)

# %%
sns.regplot(x='curb-weight',y='price',data=df)

# %%
sns.regplot(x='length',y='price',data=df)

# %%
sns.regplot(x='width',y='price',data=df)

# %%
sns.regplot(x='city-mpg',y='price',data=df)

# %%
X = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]
Y = df['price']

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X,Y)
# Out:
# LinearRegression()

# %%
x_test = [[float(input('Enter The Horse Power of the Car:')),float(input('Enter The Curb-Weight of the Car:')),float(input('Enter The Engine-Size of the Car:')),float(input('Enter The Highway MPG of the Car:'))]]
y_real = 16500.0
# Out:
# Enter The Horse Power of the Car:154.0
# Enter The Curb-Weight of the Car:2823.0
# Enter The Engine-Size of the Car:152.0
# Enter The Highway MPG of the Car:26.0

# %%
lm.predict(x_test)
# Out:
# array([19051.65470233])

# %% [markdown]
# Test Values : 154.0,2823.0,152.0,26.0
# Answer is in Dollars USD
